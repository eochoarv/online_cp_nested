# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
table = pd.read_csv('/Users/eochoa/Downloads/FNV3_2025_09_17T18_00_atcf_a_deck.txt', skiprows=6, header=None)
table.columns = ['col_'+str(x) for x in range(21)]
table['col_6'] = [float(x[:-1]) for x in table['col_6']]
table['col_7'] = [float(x[:-1]) for x in table['col_7']]
table.query('col_1 == 7').groupby('col_4').count()

table_obs = pd.read_csv('/Users/eochoa/Downloads/FNV3_2025_09_17T18_00_atcf_a_deck (2).txt', skiprows=6, header=None)
table_obs.columns = ['col_'+str(x) for x in range(21)]
table_obs['col_6'] = [float(x[:-1]) for x in table_obs['col_6']]
table_obs['col_7'] = [float(x[:-1]) for x in table_obs['col_7']]
table_obs.query('col_1 == 7').groupby('col_4').count()
# Out:
#        col_0  col_1  col_2  col_3  col_5  col_6  col_7  col_8  col_9  col_10  \
# col_4
#  F000     79     79     79     79     79     79     79     79     79      79
#  F001     98     98     98     98     98     98     98     98     98      98
#  F002     99     99     99     99     99     99     99     99     99      99
#  F003     89     89     89     89     89     89     89     89     89      89
#  F004     79     79     79     79     79     79     79     79     79      79
#  F005    120    120    120    120    120    120    120    120    120     120
#  F006     75     75     75     75     75     75     75     75     75      75
#  F007     74     74     74     74     74     74     74     74     74      74
#  F008     86     86     86     86     86     86     86     86     86      86
#  F009    106    106    106    106    106    106    106    106    106     106
#  F010     77     77     77     77     77     77     77     77     77      77
# ...

# %%
table_1 = table.query('col_1 == 7 and col_4 == " F000"')#.iloc[[x for x in range(0,80,2)],:]
table_2 = table.query('col_1 == 7 and col_4 == " F000"')#.iloc[[x for x in range(1,79,2)],:]
table_3 = table.query('col_1 == 7 and col_4 == " F001"')

# %%
table_1.groupby('col_5').count()
# Out:
# Empty DataFrame
# Columns: [col_0, col_1, col_2, col_3, col_4, col_6, col_7, col_8, col_9, col_10, col_11, col_12, col_13, col_14, col_15, col_16, col_17, col_18, col_19, col_20]
# Index: []

# %%
es = np.unique(table.query('col_1 == 7')['col_4'])

# %%
table
# Out:
#       col_0  col_1       col_2  col_3  col_4  col_5  col_6   col_7  col_8  \
# 0        AL      7  2025091718      3   F000      0  190.0   475.0     45
# 1        AL      7  2025091718      3   F000      6  193.0   491.0     41
# 2        AL      7  2025091718      3   F000     12  197.0   503.0     44
# 3        AL      7  2025091718      3   F000     12  197.0   503.0     44
# 4        AL      7  2025091718      3   F000     18  199.0   515.0     44
# ...     ...    ...         ...    ...    ...    ...    ...     ...    ...
# 15238    WP     91  2025091718      3   F049    174  404.0  1593.0     57
# 15239    WP     91  2025091718      3   F049    174  404.0  1593.0     57
# 15240    WP     91  2025091718      3   F049    174  404.0  1593.0     57
# 15241    WP     91  2025091718      3   F049    180  401.0  1603.0     48
# 15242    WP     91  2025091718      3   F049    186  414.0  1622.0     47
#
#        col_9  ... col_11  col_12 col_13  col_14  col_15  col_16  col_17  \
# ...

# %%
4*8*6
# Out:
# 192

# %%
table_mean = table.query('col_1 == 7 and col_4 != " F000"').loc[:, ['col_5', 'col_6', 'col_7']].groupby('col_5').mean()
table_mean
# Out:
#        col_6  col_7
# col_5
# 0      190.0  475.0
# 6      195.0  489.0
# 12     199.0  499.0
# 18     203.0  510.0
# 24     209.0  519.0
# 30     215.0  527.0
# 36     220.0  537.0
# 42     224.0  548.0
# 48     229.0  557.0
# 54     234.0  566.0
# 60     239.0  574.0
# 66     244.0  582.0
# 72     250.0  588.0
# 78     257.0  593.0
# 84     263.0  598.0
# 90     271.0  605.0
# 96     278.0  610.0
# 102    287.0  615.0
# 108    296.0  619.0
# 114    306.0  618.0
# 120    317.0  613.0
# 126    328.0  604.0
# 132    339.0  590.0
# 138    349.0  572.0
# 144    358.0  550.0
# 150    366.0  525.0
# 156    374.0  496.0
# 162    381.0  465.0
# 168    389.0  433.0
# 174    397.0  401.0
# 180    408.0  372.0
# 186    420.0  346.0
# 192    432.0  323.0
# 198    444.0  301.0
# 204    453.0  278.0
# 210    469.0  267.0
# 216    472.0  254.0
# 222    480.0  247.0
# 228    477.0  241.0
# 234    478.0  221.0
# 240    475.0  207.0

# %%
table_1 = table_obs.query('col_1 == 7 and col_4 == " F000" and col_5 <= 192 ').loc[:, ['col_5', 'col_6', 'col_7']].groupby('col_5').mean()
_ = plt.plot(-table_1['col_7'], table_1['col_6'], alpha=1)

table_2 = table.query('col_1 == 7 and col_5 <= 192 ').loc[:, ['col_5', 'col_6', 'col_7']].groupby('col_5').mean()
_ = plt.plot(-table_2['col_7'], table_2['col_6'], alpha=1)

# %%
for e in es:
    if e == " F000":
        alpha = 1
    else:
        alpha = .1
    table_1 = table.query('col_1 == 7 and col_4 == @e and col_5 <= 192 ').loc[:, ['col_5', 'col_6', 'col_7']].groupby('col_5').mean()
    _ = plt.plot(-table_1['col_7'], table_1['col_6'], alpha=alpha)

# %%
for e in es:
    if e == " F000":
        alpha = 1
    else:
        alpha = .1
    table_1 = table.query('col_1 == 7 and col_4 == @e').loc[:, ['col_5', 'col_6', 'col_7']].groupby('col_5').mean()
    _ = plt.plot(-table_1['col_7'], table_1['col_6'], alpha=alpha)
    
_ = plt.plot(-table_mean['col_7'], table_mean['col_6'])

# %%
table.query('col_1 == 7 and col_4 == " F000" and col_5 == 132')
# Out:
#    col_0  col_1       col_2  col_3  col_4  col_5  col_6  col_7  col_8  col_9  \
# 40    AL      7  2025091718      3   F000    132  344.0  586.0     68    984
# 41    AL      7  2025091718      3   F000    132  344.0  586.0     68    984
# 42    AL      7  2025091718      3   F000    132  344.0  586.0     68    984
#
#     ... col_11  col_12 col_13  col_14  col_15  col_16  col_17 col_18 col_19  \
# 40  ...     34     NEQ     60      63      43      46                    17
# 41  ...     50     NEQ     29      27      20      24                    17
# 42  ...     64     NEQ     13      11       9      11                    17
#
#     col_20
# 40     NaN
# 41     NaN
# 42     NaN
#
# [3 rows x 21 columns]

# %%
plt.scatter(-table_1['col_7'], table_1['col_6'])
plt.scatter(-table_2['col_7'], table_2['col_6'])
#plt.scatter(-table_3['col_7'], table_3['col_6'])
